# %% [markdown]
# # GDP, Refugees, and Education Expenditure — A Correlated Literature Review

# %% [markdown]
# ## Learning Objectives
# By the end of this lecture, you will be able to:
# - Understand how **GDP levels** influence refugee movements (origin vs. destination).
# - Evaluate the **impact of refugee inflows on host-country GDP**.
# - Analyze the relationship between **refugee numbers and education expenditure (% of GDP)**.
# - Critically connect empirical studies into a framework for your own research.

# %% [markdown]
# ## 1. Background & Motivation
#
# - Refugee movements are shaped by:
#   - **Push factors**: conflict, political repression, poverty, economic collapse.
#   - **Pull factors**: income opportunities, welfare systems, asylum policies, diaspora networks.
# - Refugees place short-term fiscal pressure on host governments, especially in **education**.
# - Central research question:
#   *How do GDP and refugee numbers interact, and how does this interaction affect education expenditure as a share of GDP?*

# %% [markdown]
# ## 2. GDP and Refugee Flows
#
# ### Origin Countries
# - **Neumayer (2005, ISQ “Bogus Refugees?”):**
#   - Cross-national asylum applications data (1980s–1990s).
#   - Found **origin GDP per capita ↓ → asylum outflows ↑**.
#   - But political repression and conflict dominate economic predictors.
# - **Hatton (2016, Economic Policy):**
#   - Panel of OECD/EU asylum inflows, 1985–2010.
#   - Confirms **negative link** between origin income levels and refugee outflows.
#   - Adds that growth shocks (GDP decline) significantly drive refugee numbers.
#
#  **Conclusion:** Lower GDP per capita at origin correlates with higher refugee outflows, though conflict remains the primary driver.

# %% [markdown]
# ### Destination Countries
# - **Neumayer (2005, EU Politics “Asylum Destination Choice”):**
#   - Modeled EU asylum seeker destinations.
#   - **Higher destination GDPpc and higher recognition rates → more applications**.
#   - Distance and diaspora networks are also strong predictors.
# - **EU-focused study (2008–2020, World Development):**
#   - First-time asylum applications to the EU.
#   - Reaffirmed GDP and asylum policy as **consistent pull factors**.
#
#   **Conclusion:** Destination GDP is a strong pull factor, but policies (recognition rates, asylum generosity) condition its effect.

# %% [markdown]
# ## 3. Refugees and Host-Country GDP
#
# - **d’Albis, Boubtane & Coulibaly (2018, Science Advances):**
#   - Studied asylum inflows into Western Europe (1985–2015).
#   - Found **positive effect of asylum inflows on GDP and employment**.
#   - No negative effect on fiscal balance in the medium run.
# - **IMF (2023 Working Paper):**
#   - Expanded dataset to global migration episodes.
#   - Used **instrumental variables & local projection methods**.
#   - Found **modest but positive GDP growth effects** from refugee inflows, especially when labor markets are flexible.
#
#  **Conclusion:** Refugee inflows are not just a fiscal cost; they can stimulate growth in the medium run.

# %% [markdown]
# ## 4. Refugees and Education Expenditure (% of GDP)
#
# ###  Global Evidence
# - **World Bank & UNHCR (2021, 2023 – Global Costing Studies):**
#   - Simulation of education costs if all refugee children enrolled in national systems.
#   - Cost ≈ **<5% of host education budgets** on average, though higher in low-income countries.
#   - Strong emphasis on international support to manage variation.
#
# ###  Country Evidence
# - **Jordan Case Study (World Bank, 2016–2019):**
#   - Syrian refugee influx → increased student numbers.
#   - Documented **budget shortfalls** and higher spending needs compared to peers at similar income levels.
#   - Reliance on donor aid to stabilize budgets.
#
# ###  Related Migration Studies
# - General immigration studies (e.g., OECD contexts):
#   - Small **negative effect on per-pupil spending** when migrant numbers rise, due to fiscal dilution.
#   - But effect sizes are context-specific.
#
#  **Conclusion:** Refugee inflows increase education expenditure needs, but relative to GDP the impact is usually modest when donor aid is considered.

# %% [markdown]
# ## 5. Comparative Evidence Table
#
# | Research Question | Dataset(s) | Analytical Approach | Key Result |
# |-------------------|------------|---------------------|------------|
# | Do higher GDP levels in origin countries reduce refugee outflows? | UNHCR, OECD, World Bank WDI | Panel regression, push–pull models | **Negative correlation**: higher GDPpc → fewer refugees leave. (Neumayer 2005; Hatton 2016) |
# | Do richer destination countries attract more asylum seekers? | Eurostat, UNHCR, WDI | Gravity model, panel regression | **Positive correlation**: higher destination GDPpc + recognition rates → more applications. (Neumayer 2005; EU 2008–2020) |
# | Do refugee inflows affect host-country GDP growth? | UNHCR inflows + IMF & WB macro data | IV & local projections, macro panel | **Modest positive GDP growth**, fiscal impact neutral/positive. (d’Albis et al. 2018; IMF 2023) |
# | How costly is refugee education relative to GDP? | WB–UNHCR costing models, host budgets | Costing simulations | Educating all refugees ≈ *<5% of education budgets*; varies by income group. (WB–UNHCR 2021, 2023) |
# | How do refugees affect host education expenditure? | Jordan case study; WDI | Budget analysis, FE regressions | Refugee inflows → **budget shortfalls**, pressure on per-pupil spending. (WB Jordan study; migration–education studies) |
# | **OUR Project**: How do refugee inflows interact with host GDP and shape education expenditure (% of GDP)? | UNHCR refugee stats + WDI (GDP, education expenditure, controls) | Panel regression w/ FE; IV (shift–share instruments) | Hypothesis: Refugee inflows → ↑ education expenditure (% GDP), moderated by host GDP & donor aid. |

# %% [markdown]
# ## 6. Research Design Implications (for your project)
#
# - **Datasets:**
#   - UNHCR Population Statistics (refugees by host country, year).
#   - World Bank WDI (GDP, GDP per capita, education expenditure % of GDP).
#   - Controls: unemployment, school-age population share, ODA for education, asylum recognition rates.
# - **Approach:**
#   - Two-way fixed effects panel regression.
#   - IV strategy: Shift–share instrument (origin shocks × historical settlement shares).
# - **Interpretation:**
#   - Compare your coefficients with WB–UNHCR costing benchmarks (<5%).
#   - Check heterogeneity by income level, policy restrictiveness, and donor aid flows.

# %% [markdown]
# ## 7. Discussion Questions
#
# 1. Why do GDP effects differ between **origin** and **destination** contexts?
# 2. How can we distinguish **refugees affecting GDP** vs. **GDP affecting refugees**?
# 3. What mechanisms link refugee inflows to **education spending**?
# 4. How might international donor aid mediate the budgetary effects?
# 5. How should low-income vs. high-income hosts be compared?

# %% [markdown]
# ## 8. Key References
#
# - Hatton, T. (2016). *Asylum Migration to the OECD: Determinants and Policy.* Economic Policy.
# - Neumayer, E. (2005). *Asylum Destination Choice: What Makes Some Countries More Attractive Than Others?* European Union Politics.
# - Neumayer, E. (2005). *Bogus Refugees? The Determinants of Asylum Migration to Western Europe.* International Studies Quarterly.
# - d’Albis, H., Boubtane, E., & Coulibaly, D. (2018). *Macroeconomic Evidence on Asylum Seekers in Europe.* Science Advances.
# - IMF (2023). *Refugees and GDP Growth: Evidence from Migration Episodes.*
# - World Bank & UNHCR (2021, 2023). *Global Cost of Inclusive Refugee Education.*
# - World Bank (2016–2019). *Jordan Education and Refugees Case Studies.*

# %% [markdown]
# ## Summary
#
# - **Origin GDP ↓ → Refugee outflows ↑** (poverty + conflict drive flight).
# - **Destination GDP ↑ → Refugee inflows ↑** (pull factor, moderated by policy).
# - **Refugee inflows → GDP growth** in medium run, fiscal neutral/positive.
# - **Education expenditure (% GDP)** rises with refugee numbers but usually manageable relative to GDP when donors contribute.
# - **Your research** extends this by explicitly testing the correlation between **refugee inflows, host GDP, and education expenditure % of GDP**.

# %% [markdown]
# # 2 Groups
#
# ## 🌍 Origin Countries (Refugee-Producing)
#
# (Main sources of refugee outflows due to conflict, instability, repression, or disasters)
#
# **APAC**
#
# 	•	Afghanistan
# 	•	Bangladesh (Rohingya crisis spillover from Myanmar, though also a host)
# 	•	Bhutan (small but historically produced refugees in Nepal camps)
# 	•	Korea, Dem. People’s Rep.
# 	•	Myanmar
# 	•	Nepal (minor outflows historically)
# 	•	Pakistan (both host & producer, but produces refugees due to instability)
# 	•	Sri Lanka (historically Tamil refugee outflows)
# 	•	Timor-Leste (small historic outflow)
# 	•	Vietnam (historic, small today)
#
# **EMEA**
#
# 	•	Albania (historic outflows in 1990s, smaller today)
# 	•	Algeria (some Sahrawi refugee movements)
# 	•	Armenia (Nagorno-Karabakh)
# 	•	Azerbaijan (Nagorno-Karabakh conflict, IDPs/refugees)
# 	•	Belarus (political repression, but smaller scale)
# 	•	Bosnia and Herzegovina (historic, small now)
# 	•	Burkina Faso (recent conflict-driven outflows)
# 	•	Burundi
# 	•	Cameroon (Anglophone crisis)
# 	•	Central African Republic
# 	•	Chad
# 	•	Congo, Dem. Rep.
# 	•	Congo, Rep.
# 	•	Cote d’Ivoire (historic conflict)
# 	•	Djibouti (small)
# 	•	Egypt, Arab Rep. (both host & origin, some outflow)
# 	•	Eritrea (major producer)
# 	•	Ethiopia (civil war, Tigray crisis)
# 	•	Gambia (historic)
# 	•	Georgia (Abkhazia, South Ossetia)
# 	•	Guinea
# 	•	Guinea-Bissau
# 	•	Iran, Islamic Rep. (also host, but produces political refugees)
# 	•	Iraq
# 	•	Jordan (small origin, mostly host though)
# 	•	Kosovo
# 	•	Kyrgyz Republic (minor)
# 	•	Lebanon (outmigration, political refugees)
# 	•	Liberia (historic, small now)
# 	•	Libya
# 	•	Mali
# 	•	Mauritania (historic refugee production)
# 	•	Moldova (small outflow)
# 	•	Morocco (minor, more transit country)
# 	•	Niger
# 	•	Nigeria (Boko Haram, conflict)
# 	•	North Macedonia (historic, small)
# 	•	Somalia (longstanding refugee source)
# 	•	South Sudan (major source)
# 	•	Sudan (Darfur, civil conflict)
# 	•	Syrian Arab Republic (largest refugee-producing country worldwide)
# 	•	Tajikistan (historic, small now)
# 	•	Tanzania (produced Burundian refugees historically, now more host)
# 	•	Togo (historic)
# 	•	Tunisia (political repression outflow, small)
# 	•	Turkey (also destination, but produces Kurdish asylum seekers)
# 	•	Turkmenistan (political exile cases)
# 	•	Uganda (mainly host, small origin)
# 	•	Ukraine (post-2022 war, major refugee origin)
# 	•	Uzbekistan (small exile)
# 	•	West Bank and Gaza (Palestinian refugees)
# 	•	Yemen, Rep.
# 	•	Zambia (historic outflows)
# 	•	Zimbabwe (economic migrants/refugees)
#
# **LATAM**
#
# 	•	Cuba
# 	•	El Salvador (gang violence)
# 	•	Guatemala
# 	•	Haiti (major refugee origin)
# 	•	Honduras
# 	•	Nicaragua
# 	•	Venezuela, RB (largest refugee crisis in LATAM)
#
# **NA**
#
# 	•	None (U.S. & Canada are primarily destinations).
#
#
#
# ## 🌎 Destination Countries (Refugee-Hosting / High GDP)
#
# (Main receivers of refugees, due to geography, asylum systems, or high GDP)
#
# **APAC**
#
# 	•	Australia
# 	•	Japan (low intake, but destination)
# 	•	Korea, Rep.
# 	•	Malaysia (hosts many Rohingya)
# 	•	Thailand (hosts Myanmar refugees)
# 	•	Indonesia (transit, some hosting)
# 	•	India (hosts Tibetans, Rohingya, Afghans)
# 	•	New Zealand (small resettlement)
# 	•	Singapore (not major asylum, but destination economy)
#
# **EMEA**
#
# 	•	Austria
# 	•	Belgium
# 	•	Cyprus
# 	•	Czech Republic
# 	•	Denmark
# 	•	Estonia
# 	•	Finland
# 	•	France
# 	•	Germany (major destination in Europe)
# 	•	Greece (frontline EU host)
# 	•	Hungary (frontline EU host)
# 	•	Ireland
# 	•	Israel (asylum applications, restrictive though)
# 	•	Italy (Mediterranean arrivals)
# 	•	Luxembourg
# 	•	Malta (Mediterranean arrivals)
# 	•	Netherlands
# 	•	Norway
# 	•	Poland (hosts millions of Ukrainians)
# 	•	Portugal
# 	•	Romania (hosts Ukrainians)
# 	•	Russian Federation (hosts Ukrainians, Central Asians)
# 	•	Spain
# 	•	Sweden (major asylum destination)
# 	•	Switzerland (hosts many refugees)
# 	•	Turkey (world’s largest refugee host, >3 million Syrians)
# 	•	United Arab Emirates (not refugee host, but destination for migrants)
# 	•	United Kingdom
#
# **LATAM**
#
# 	•	Argentina (Venezuelans)
# 	•	Brazil (Venezuelans)
# 	•	Chile (Venezuelans, Haitians)
# 	•	Colombia (largest Venezuelan host ~2.5M)
# 	•	Costa Rica (Nicaraguans)
# 	•	Dominican Republic (Haitians)
# 	•	Ecuador (Venezuelans, Colombians)
# 	•	Mexico (both transit & destination for Central Americans)
# 	•	Panama (transit & some destination)
# 	•	Peru (hosts 1M+ Venezuelans)
# 	•	Uruguay (small)
#
# **NA**
#
# 	•	Canada (major refugee resettlement country)
# 	•	United States (major refugee resettlement country + asylum seekers)
#
# ⸻
#
# This split gives you Origin vs Destination classification, but note:
#
# 	•	Some countries appear in both lists (e.g., Pakistan, Turkey, Iran, Egypt, Bangladesh, Colombia) → they are simultaneous refugee hosts and producers.
# 	•	You may want to create a third category = “Mixed (Origin + Destination)” to capture those cases for clarity in your dataset.

# %% [markdown]
# # 📊 Refugee Origin vs Destination vs Mixed Dataset

# %% [markdown]
# | Origin Countries           | Destination Countries | Mixed (Both Origin & Destination) |
# |-----------------------------|-----------------------|-----------------------------------|
# | Afghanistan                 | Australia             | Bangladesh                        |
# | Albania                     | Austria               | Egypt, Arab Rep.                  |
# | Algeria                     | Belgium               | Iran, Islamic Rep.                |
# | Angola                      | Canada                | Jordan                            |
# | Armenia                     | Chile                 | Pakistan                          |
# | Azerbaijan                  | Colombia              | Turkey                            |
# | Belarus                     | Costa Rica            | Venezuela, RB                     |
# | Benin                       | Denmark               | Iraq                              |
# | Bhutan                      | Ecuador               | Lebanon                           |
# | Bolivia                     | Finland               | Sudan                             |
# | Bosnia and Herzegovina      | France                | South Sudan                       |
# | Burkina Faso                | Germany               | Uganda                            |
# | Burundi                     | Greece                | Ethiopia                          |
# | Cabo Verde                  | Hungary               | Nigeria                           |
# | Cambodia                    | Ireland               | Colombia                          |
# | Cameroon                    | Israel                | Kenya                             |
# | Central African Republic    | Italy                 |                                   |
# | Chad                        | Japan                 |                                   |
# | China                       | Luxembourg            |                                   |
# | Comoros                     | Malta                 |                                   |
# | Congo, Dem. Rep.            | Mexico                |                                   |
# | Congo, Rep.                 | Netherlands           |                                   |
# | Cuba                        | New Zealand           |                                   |
# | Cote d'Ivoire               | Norway                |                                   |
# | Djibouti                    | Peru                  |                                   |
# | El Salvador                 | Poland                |                                   |
# | Equatorial Guinea           | Portugal              |                                   |
# | Eritrea                     | Romania               |                                   |
# | Eswatini                    | Russian Federation    |                                   |
# | Gambia                      | Spain                 |                                   |
# | Georgia                     | Sweden                |                                   |
# | Ghana                       | Switzerland           |                                   |
# | Guinea                      | United Kingdom        |                                   |
# | Guinea-Bissau               | United States         |                                   |
# | Haiti                       | Turkey                |                                   |
# | Honduras                    | Brazil                |                                   |
# | Kosovo                      | Argentina             |                                   |
# | Kyrgyz Republic             |                       |                                   |
# | Liberia                     |                       |                                   |
# | Libya                       |                       |                                   |
# | Madagascar                  |                       |                                   |
# | Malawi                      |                       |                                   |
# | Mali                        |                       |                                   |
# | Mauritania                  |                       |                                   |
# | Moldova                     |                       |                                   |
# | Mongolia                    |                       |                                   |
# | Morocco                     |                       |                                   |
# | Mozambique                  |                       |                                   |
# | Myanmar                     |                       |                                   |
# | Nepal                       |                       |                                   |
# | Nicaragua                   |                       |                                   |
# | Niger                       |                       |                                   |
# | North Macedonia             |                       |                                   |
# | Rwanda                      |                       |                                   |
# | Sierra Leone                |                       |                                   |
# | Somalia                     |                       |                                   |
# | Syrian Arab Republic        |                       |                                   |
# | Tajikistan                  |                       |                                   |
# | Togo                        |                       |                                   |
# | Tunisia                     |                       |                                   |
# | Turkmenistan                |                       |                                   |
# | Ukraine                     |                       |                                   |
# | Uzbekistan                  |                       |                                   |
# | West Bank and Gaza          |                       |                                   |
# | Yemen, Rep.                 |                       |                                   |
# | Zambia                      |                       |                                   |
# | Zimbabwe                    |                       |                                   |

# %%
df <- read.csv('/content/sample_data/refugee_data.csv')
df
# Out:
#    Origin                   Destination        Mixed
# 1  Afghanistan              Australia          Bangladesh
# 2  Albania                  Austria            Egypt, Arab Rep.
# 3  Algeria                  Belgium            Iran, Islamic Rep.
# 4  Angola                   Canada             Jordan
# 5  Armenia                  Chile              Pakistan
# 6  Azerbaijan               Colombia           Turkey
# 7  Belarus                  Costa Rica         Venezuela, RB
# 8  Benin                    Denmark            Iraq
# 9  Bhutan                   Ecuador            Lebanon
# 10 Bolivia                  Finland            Sudan
# 11 Bosnia and Herzegovina   France             South Sudan
# 12 Burkina Faso             Germany            Uganda
# 13 Burundi                  Greece             Ethiopia
# 14 Cabo Verde               Hungary            Nigeria
# 15 Cambodia                 Ireland            Colombia
# 16 Cameroon                 Israel             Kenya
# ...
